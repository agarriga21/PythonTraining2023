# %%
import pandas as pd

poke = pd.read_csv('pokemon_data.csv')

print(poke.tail(5))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df = pd.read_csv('pokemon_data.csv')
print(df.tail(5))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
print(df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
print(df.iloc[1:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
print(df.iloc[2,1])
# Out:
# Venusaur

# %%
df['Type 1']
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense']

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    143
# 1       80     60           1      False    185
# 2      100     80           1      False    245
# 3      120     80           1      False    303
# 4       50     65           1      False    134

# %%
cols = list(df.columns)
df=df[cols[0:4]+[cols[-1]]+cols[4:12]]

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    143  45      49       49
# 1  2                Ivysaur  Grass  Poison    185  60      62       63
# 2  3               Venusaur  Grass  Poison    245  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    303  80     100      123
# 4  4             Charmander   Fire     NaN    134  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
import re
df.loc[df['Name'].str.contains('^P(?=id)[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                 Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 20    16               Pidgey  Normal  Flying    125  40      45       40
# 21    17            Pidgeotto  Normal  Flying    178  63      60       55
# 22    18              Pidgeot  Normal  Flying    238  83      80       75
# 23    18  PidgeotMega Pidgeot  Normal  Flying    243  83      80       80
# 578  519               Pidove  Normal  Flying    155  50      55       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 20        35       35     56           1      False
# 21        50       50     71           1      False
# 22        70       70    101           1      False
# 23       135       80    121           1      False
# 578       36       30     43           5      False

# %%
import re
for x in sv.index:
    df[x,'Name'].str.contains('^P(?=id)[a-z]*',flags=re.I,regex=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (0, 'Name')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sv = pd.read_csv('salesviewminiproject.csv')

# %%
print(sv)
# Out:
#     Customer Name    Product Name  Employee Name         Location  \
# 0       Tony Hall           Skirt      Amy Gomez  San Antonio, TX
# 1       Tony Hall        Lego Set    Jacob Frank  San Antonio, TX
# 2       Tony Hall  Protein Powder    Jacob Frank  San Antonio, TX
# 3       Tony Hall      Desk chair     John Adams  San Antonio, TX
# 4       Tony Hall  Foldable Table      Amy Gomez  San Antonio, TX
# ..            ...             ...            ...              ...
# 621  Patrick Scar         T-shirt  Adam Goodyear        Tulsa, OK
# 622  Patrick Scar  Protein Powder  Adam Goodyear        Tulsa, OK
# 623  Patrick Scar         Toy Car  Adam Goodyear        Tulsa, OK
# 624  Patrick Scar         Noodles   Jessica Kent        Tulsa, OK
# 625  Patrick Scar     Barbie Doll  Adam Goodyear        Tulsa, OK
#
#      Quantity Purchased Total Price     Time of Purchase Store Profit
# 0                    20     $299.80  2023-01-09 11:26:28      $174.80
# ...

# %%
print(sv.iloc[1:4])
# Out:
#   Customer Name    Product Name Employee Name         Location  \
# 1     Tony Hall        Lego Set   Jacob Frank  San Antonio, TX
# 2     Tony Hall  Protein Powder   Jacob Frank  San Antonio, TX
# 3     Tony Hall      Desk chair    John Adams  San Antonio, TX
#
#    Quantity Purchased Total Price     Time of Purchase Store Profit
# 1                   2      $51.98  2023-01-09 11:28:19       $41.98
# 2                  25     $849.75  2023-01-09 11:28:19      $724.75
# 3                   7     $419.93  2023-01-09 11:28:19      $313.18

# %%
sv
# Out:
#     Customer Name    Product Name  Employee Name         Location  \
# 0       Tony Hall           Skirt      Amy Gomez  San Antonio, TX
# 1       Tony Hall        Lego Set    Jacob Frank  San Antonio, TX
# 2       Tony Hall  Protein Powder    Jacob Frank  San Antonio, TX
# 3       Tony Hall      Desk chair     John Adams  San Antonio, TX
# 4       Tony Hall  Foldable Table      Amy Gomez  San Antonio, TX
# ..            ...             ...            ...              ...
# 621  Patrick Scar         T-shirt  Adam Goodyear        Tulsa, OK
# 622  Patrick Scar  Protein Powder  Adam Goodyear        Tulsa, OK
# 623  Patrick Scar         Toy Car  Adam Goodyear        Tulsa, OK
# 624  Patrick Scar         Noodles   Jessica Kent        Tulsa, OK
# 625  Patrick Scar     Barbie Doll  Adam Goodyear        Tulsa, OK
#
#      Quantity Purchased Total Price     Time of Purchase Store Profit
# 0                    20     $299.80  2023-01-09 11:26:28      $174.80
# ...

# %%
sv.loc[sv['Employee Name'].str.contains('^A[a-z]*',flags=re.I,regex=True)]
# Out:
#     Customer Name    Product Name  Employee Name         Location  \
# 0       Tony Hall           Skirt      Amy Gomez  San Antonio, TX
# 4       Tony Hall  Foldable Table      Amy Gomez  San Antonio, TX
# 6       Tony Hall      Desk chair      Amy Gomez  San Antonio, TX
# 9       Tony Hall  Foldable Table      Amy Gomez  San Antonio, TX
# 10      Tony Hall  Protein Powder      Amy Gomez  San Antonio, TX
# ..            ...             ...            ...              ...
# 619  Patrick Scar          Shorts  Adam Goodyear        Tulsa, OK
# 621  Patrick Scar         T-shirt  Adam Goodyear        Tulsa, OK
# 622  Patrick Scar  Protein Powder  Adam Goodyear        Tulsa, OK
# 623  Patrick Scar         Toy Car  Adam Goodyear        Tulsa, OK
# 625  Patrick Scar     Barbie Doll  Adam Goodyear        Tulsa, OK
#
#      Quantity Purchased Total Price     Time of Purchase Store Profit
# 0                    20     $299.80  2023-01-09 11:26:28      $174.80
# ...

# %%
sv.loc[sv['Product Name'].str.contains('Table')]
# Out:
#        Customer Name    Product Name  Employee Name         Location  \
# 4          Tony Hall  Foldable Table      Amy Gomez  San Antonio, TX
# 9          Tony Hall  Foldable Table      Amy Gomez  San Antonio, TX
# 11         Tony Hall  Foldable Table      Amy Gomez  San Antonio, TX
# 26         Tony Hall  Foldable Table     John Adams  San Antonio, TX
# 37         Tony Hall  Foldable Table     John Adams  San Antonio, TX
# 42         Tony Hall  Foldable Table      Amy Gomez  San Antonio, TX
# 44         Tony Hall  Foldable Table    Jacob Frank  San Antonio, TX
# 45         Tony Hall  Foldable Table      Amy Gomez  San Antonio, TX
# 72       Tim Jenkins  Foldable Table      Amy Gomez  San Antonio, TX
# 88       Tim Jenkins  Foldable Table     John Adams  San Antonio, TX
# 96       Tim Jenkins  Foldable Table    Jacob Frank  San Antonio, TX
# 111      Tim Jenkins  Foldable Table    Jacob Frank  San Antonio, TX
# 116      Tim Jenkins  Foldable Table    Jacob Frank  San Antonio, TX
# ...

# %%
sv.iloc[:,4].sum(0)
# Out:
# 8440

# %%
sv["Quantity Purchased"].mean(0)
# Out:
# 13.482428115015974

# %%
sv.describe()
# Out:
#        Quantity Purchased
# count          626.000000
# mean            13.482428
# std              7.057513
# min              1.000000
# 25%              7.000000
# 50%             14.000000
# 75%             20.000000
# max             25.000000

# %%
8440/626
# Out:
# 13.482428115015974

# %%
sv['Test'] = sv["Quantity Purchased"]*5

# %%
print(sv)
# Out:
#     Customer Name    Product Name  Employee Name         Location  \
# 0       Tony Hall           Skirt      Amy Gomez  San Antonio, TX
# 1       Tony Hall        Lego Set    Jacob Frank  San Antonio, TX
# 2       Tony Hall  Protein Powder    Jacob Frank  San Antonio, TX
# 3       Tony Hall      Desk chair     John Adams  San Antonio, TX
# 4       Tony Hall  Foldable Table      Amy Gomez  San Antonio, TX
# ..            ...             ...            ...              ...
# 621  Patrick Scar         T-shirt  Adam Goodyear        Tulsa, OK
# 622  Patrick Scar  Protein Powder  Adam Goodyear        Tulsa, OK
# 623  Patrick Scar         Toy Car  Adam Goodyear        Tulsa, OK
# 624  Patrick Scar         Noodles   Jessica Kent        Tulsa, OK
# 625  Patrick Scar     Barbie Doll  Adam Goodyear        Tulsa, OK
#
#      Quantity Purchased Total Price     Time of Purchase Store Profit  Test
# 0                    20     $299.80  2023-01-09 11:26:28      $174.80   100
# ...

# %%
print(sv.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer Name       626 non-null    object
#  1   Product Name        626 non-null    object
#  2   Employee Name       626 non-null    object
#  3   Location            626 non-null    object
#  4   Quantity Purchased  626 non-null    int64
#  5   Total Price         626 non-null    object
#  6   Time of Purchase    626 non-null    object
#  7   Store Profit        626 non-null    object
#  8   Test                626 non-null    int64
# dtypes: int64(2), object(7)
# memory usage: 44.1+ KB
# None

# %%
for x in sv.index:
    if sv.loc[x, "Quantity Purchased"] > 20:
        sv.drop(x, inplace = True)

# %%
for x in sv.index:
    if sv.loc[x, "Quantity Purchased"] > 20:
        sv.drop(x, inplace = True)

# %%
for x in sv.index:
    if sv.loc[x, "Quantity Purchased"] > 10:
        print(sv.loc[x,'Total Price'])
# Out:
# $299.80
# $799.80
# $239.84
# $719.82
# $509.85
# $679.83
# $31.50
# $21.89
# $179.88
# $254.83
# $31.84
# $389.85
# $719.82
# $399.80
# $39.80
# $441.87
# $159.84
# $209.86
# $36.00
# $719.82
# $109.89
# $759.81
# $679.83
# $493.81
# $169.83
# $21.89
# $254.83
# $164.89
# $139.86
# $285.89
# $179.82
# $179.88
# $719.82
# $279.86
# $611.82
# $373.89
# $299.85
# $1,019.83
# $17.82
# $475.86
# $719.88
# $39.80
# $959.84
# $239.84
# $179.88
# $299.80
# $129.87
# $1,199.80
# $164.89
# $21.89
# $16.83
# $779.87
# $559.86
# $373.89
# $475.86
# $109.89
# $19.80
# $284.81
# $1,019.83
# $493.81
# $159.84
# $1,019.83
# $559.86
# $194.87
# $179.82
# $379.81
# $719.88
# $23.88
# $1,019.83
# $11.88
# $899.85
# $337.87
# $179.82
# $719.88
# $194.87
# $164.89
# $29.85
# $149.85
# $42.75
# $479.88
# $149.85
# $299.85
# $254.83
# $189.81
# $169.83
# $899.85
# $39.80
# $169.83
# $239.84
# $179.82
# $27.86
# $359.82
# $129.87
# $284.81
# $164.89
# $199.80
# $299.80
# $467.82
# $194.87
# $11.88
# ...

# %%
sv["Quantity Type"] = "null"

# %%
for x in sv.index:
    if sv.loc[x, "Quantity Purchased"] > 10:
        sv.loc[x,"Quantity Type"] = "High Amount"
    elif sv.loc[x, "Quantity Purchased"] == 10:
        sv.loc[x,"Quantity Type"] = "10 Amount"
    elif sv.loc[x, "Quantity Purchased"] == 9:
        sv.loc[x,"Quantity Type"] = "9 Amount"
    elif sv.loc[x, "Quantity Purchased"] == 8:
        sv.loc[x,"Quantity Type"] = "8 Amount"
    elif sv.loc[x, "Quantity Purchased"] == 7:
        sv.loc[x,"Quantity Type"] = "7 Amount"
    elif sv.loc[x, "Quantity Purchased"] == 6:
        sv.loc[x,"Quantity Type"] = "6 Amount"
    else:
        sv.loc[x,"Quantity Type"] = "Low"

# %%
print(sv[["Quantity Purchased","Quantity Type"]].head(20))
# Out:
#     Quantity Purchased Quantity Type
# 0                   20   High Amount
# 1                    2           Low
# 3                    7      7 Amount
# 4                   20   High Amount
# 6                    4           Low
# 7                   16   High Amount
# 9                   18   High Amount
# 10                  15   High Amount
# 11                  17   High Amount
# 12                  14   High Amount
# 13                  11   High Amount
# 14                   3           Low
# 16                  10     10 Amount
# 17                  12   High Amount
# 18                  17   High Amount
# 21                   6      6 Amount
# 23                  16   High Amount
# 24                   9      9 Amount
# 25                  15   High Amount
# 26                  18   High Amount

# %% [markdown]
# #### print(sv["Product Name"].duplicated())

# %%
sv['Price Int'] =  sv["Total Price"].replace('[\$,]', '', regex=True).astype(float)

# %%
print(sv)
# Out:
#     Customer Name    Product Name  Employee Name         Location  \
# 0       Tony Hall           Skirt      Amy Gomez  San Antonio, TX
# 1       Tony Hall        Lego Set    Jacob Frank  San Antonio, TX
# 3       Tony Hall      Desk chair     John Adams  San Antonio, TX
# 4       Tony Hall  Foldable Table      Amy Gomez  San Antonio, TX
# 6       Tony Hall      Desk chair      Amy Gomez  San Antonio, TX
# ..            ...             ...            ...              ...
# 621  Patrick Scar         T-shirt  Adam Goodyear        Tulsa, OK
# 622  Patrick Scar  Protein Powder  Adam Goodyear        Tulsa, OK
# 623  Patrick Scar         Toy Car  Adam Goodyear        Tulsa, OK
# 624  Patrick Scar         Noodles   Jessica Kent        Tulsa, OK
# 625  Patrick Scar     Barbie Doll  Adam Goodyear        Tulsa, OK
#
#      Quantity Purchased Total Price     Time of Purchase Store Profit  Test  \
# 0                    20     $299.80  2023-01-09 11:26:28      $174.80   100
# ...

# %%
sv['Profit Float'] =  sv["Store Profit"].replace('[\$,]', '', regex=True).astype(float)

# %%
sv.groupby(["Customer Name","Employee Name"])["Profit Float"].agg(["mean","sum","count"]).round(2)
# Out:
#                                  mean      sum  count
# Customer Name   Employee Name
# Andrew Shultz   Hailey Munoz   173.45  3642.41     21
#                 Manuel Gomez   116.92  2922.88     25
# Bob Billy       Hailey Munoz   118.68  2967.01     25
#                 Manuel Gomez   133.36  1867.06     14
# Dillon Cox      Adam Goodyear  305.10  3050.99     10
#                 Jessica Kent   127.44  2039.01     16
# Guy Goodwin     Amy Gomez      188.58  2263.00     12
#                 Jacob Frank    198.35  2181.88     11
#                 John Adams      91.20   547.18      6
#                 John Smith     196.89  1968.92     10
# Hadly Hall      Amy Gomez      132.10  4491.51     34
#                 Jacob Frank    140.43  3931.98     28
#                 John Adams     195.43  3322.38     17
#                 John Smith     108.50  2387.00     22
# Madelyn Mathews Edward Eaton   184.03  2576.43     14
#                 Larry Lobster  169.26  3723.68     22
# ...

# %%
types = pd.read_csv('types.csv')

# %%
print(types)
# Out:
#     Type
# 0    Toy
# 1  Table
# 2  Chair
# 3  Skirt
# 4  Shirt

# %%
sv['Types'] = "null"

# %%
types.loc[0,"Type"]
# Out:
# 'Toy'

# %%
types.iat[0,0]
# Out:
# 'Toy'

# %%
print(sv[["Product Name","Types"]].head(40))
# Out:
#       Product Name  Types
# 0            Skirt   null
# 1         Lego Set   Toys
# 3       Desk chair  Chair
# 4   Foldable Table  Table
# 6       Desk chair  Chair
# 7          T-shirt   null
# 9   Foldable Table  Table
# 10  Protein Powder   Food
# 11  Foldable Table  Table
# 12         Toy Car    Toy
# 13         Noodles   Food
# 14            Hats   null
# 16         T-shirt   null
# 17         T-shirt   null
# 18         T-shirt   null
# 21        Lego Set   Toys
# 23         Noodles   Food
# 24          Shorts   null
# 25        Lego Set   Toys
# 26  Foldable Table  Table
# 28  Foldable Chair  Chair
# 29         Toy Car    Toy
# 30         Noodles   Food
# 31          Shorts   null
# 32  Protein Powder   Food
# 33         Noodles   Food
# 34     Barbie Doll   null
# 35           Skirt   null
# 36  Foldable Chair  Chair
# 37  Foldable Table  Table
# 38         Noodles   Food
# 40         Toy Car    Toy
# 41      Desk chair  Chair
# 42  Foldable Table  Table
# ...

# %%
#Different name change for type
sv.loc[sv['Product Name'].str.contains('Lego'), 'Types']=('Toys')

# %%
#loop for same name as regex
for x in types.index:
    sv.loc[sv['Product Name'].str.contains(types.loc[x,"Type"],flags=re.I,regex=True), 'Types']=(types.loc[x,"Type"])

# %%
for x in types.index:
    print(types.loc[x,"Type"])
# Out:
# Toy
# Table
# Chair
# Skirt
# Shirt

# %%
list1 = ["Toy","Table","Chair"]
print(list1[0])
print(list1.length)
# Out:
# Toy

# %%
#loop for same name as regex
for x in list1:
    sv.loc[sv['Product Name'].str.contains(x,flags=re.I,regex=True), 'Types']=(x)

# %%
foodlist = ["Noodles","Protein"]
print(foodlist)
# Out:
# ['Noodles', 'Protein']

# %%
for x in foodlist:
    sv.loc[sv['Product Name'].str.contains(x,flags=re.I,regex=True), 'Types']=("Food")

# %%
sv.corr()
# Out:
#                     Quantity Purchased      Test  Price Int  Profit Float
# Quantity Purchased            1.000000  1.000000   0.504902      0.499911
# Test                          1.000000  1.000000   0.504902      0.499911
# Price Int                     0.504902  0.504902   1.000000      0.996065
# Profit Float                  0.499911  0.499911   0.996065      1.000000

# %%
df.corr()
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097614  0.102298  0.094786  0.088759  0.085817
# HP          0.097614  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102298  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094786  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.088759  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085817  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.010733  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.982516  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.153396  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# #           0.010733    0.982516   0.153396
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# ...

# %%
sv["Price Int"].add_prefix('Price_')
# Out:
# Price_0      299.80
# Price_1       51.98
# Price_3      419.93
# Price_4      799.80
# Price_6      239.96
#               ...
# Price_621     59.96
# Price_622    373.89
# Price_623      4.50
# Price_624     25.87
# Price_625    109.89
# Name: Price Int, Length: 488, dtype: float64

# %%
print(sv.head(5))
# Out:
#   Customer Name    Product Name         Employee Name         Location  \
# 0     Tony Hall           Skirt    Employee Amy Gomez  San Antonio, TX
# 1     Tony Hall        Lego Set  Employee Jacob Frank  San Antonio, TX
# 3     Tony Hall      Desk chair   Employee John Adams  San Antonio, TX
# 4     Tony Hall  Foldable Table    Employee Amy Gomez  San Antonio, TX
# 6     Tony Hall      Desk chair    Employee Amy Gomez  San Antonio, TX
#
#    Quantity Purchased Total Price     Time of Purchase Store Profit  Test  \
# 0                  20     $299.80  2023-01-09 11:26:28      $174.80   100
# 1                   2      $51.98  2023-01-09 11:28:19       $41.98    10
# 3                   7     $419.93  2023-01-09 11:28:19      $313.18    35
# 4                  20     $799.80  2023-01-09 11:28:19      $599.80   100
# 6                   4     $239.96  2023-01-09 11:28:19      $178.96    20
#
#    Price Int  Profit Float Quantity Type  Types  Price $
# ...

# %%
sv["Employee Name"] = "Employee "+sv["Employee Name"]
